# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Import Dataset

# %%
moviedata = pd.read_csv('Final-CLEAN-Dataset.csv')
moviedata.head(n = 10)
# Out:
#    ID                              Title  Age of Movie Age Category  IMDb  \
# 0   1                          Inception            12          13+   8.8
# 1   2                         The Matrix            23          18+   8.7
# 2   3             Avengers: Infinity War             4          13+   8.5
# 3   4                 Back to the Future            37           7+   8.5
# 4   5     The Good, the Bad and the Ugly            56          18+   8.8
# 5   6  Spider-Man: Into the Spider-Verse             4           7+   8.4
# 6   7                        The Pianist            20          18+   8.5
# 7   8                   Django Unchained            10          18+   8.4
# 8   9            Raiders of the Lost Ark            41           7+   8.4
# 9  10               Inglourious Basterds            13          18+   8.3
#
#    Rotten  Availability          Directors     Genres         Country  \
# 0    87.0             1  Christopher Nolan     Action   United States
# 1    87.0             1     Lana Wachowski     Action   United States
# 2    84.0             1      Anthony Russo     Action   United States
# 3    96.0             1    Robert Zemeckis  Adventure   United States
# 4    97.0             2       Sergio Leone    Western           Italy
# 5    97.0             1    Bob Persichetti  Animation   United States
# 6    95.0             2     Roman Polanski  Biography  United Kingdom
# 7    87.0             1  Quentin Tarantino      Drama   United States
# 8    95.0             1   Steven Spielberg     Action   United States
# 9    89.0             1  Quentin Tarantino  Adventure         Germany
#
#   Language  Runtime
# 0  English    148.0
# 1  English    136.0
# 2  English    149.0
# 3  English    116.0
# 4  Italian    161.0
# 5  English    117.0
# 6  English    150.0
# 7  English    165.0
# 8  English    115.0
# 9  English    153.0

# %%
moviedata.describe()
# Out:
#                 ID  Age of Movie         IMDb       Rotten  Availability  \
# count  5556.000000   5556.000000  5556.000000  5556.000000   5556.000000
# mean   4383.358711     14.583693     6.230148    60.207163      1.055796
# std    2681.552727     13.990212     1.078126    22.265142      0.234205
# min       1.000000      1.000000     1.100000     2.000000      1.000000
# 25%    1987.750000      5.000000     5.600000    45.000000      1.000000
# 50%    4451.500000     10.000000     6.300000    61.000000      1.000000
# 75%    6802.250000     19.000000     7.000000    77.000000      1.000000
# max    9380.000000    120.000000     9.000000   100.000000      3.000000
#
#            Runtime
# count  5556.000000
# mean    100.980202
# std      22.003043
# min       2.000000
# 25%      90.000000
# 50%      99.000000
# 75%     110.250000
# max     359.000000

# %%
# Quantile 25% and 75%
Q1 = moviedata['Runtime'].quantile(0.25)
Q3 = moviedata['Runtime'].quantile(0.75)

#Interquartile range (IQR)
IQR = Q3 - Q1

# Remove the outliers
moviedata = moviedata.drop(moviedata[(moviedata['Runtime'] <= Q1 - 1.5*IQR) | (moviedata['Runtime'] >= Q3 + 1.5*IQR)].index)
moviedata
# Out:
#         ID                              Title  Age of Movie Age Category  \
# 1        2                         The Matrix            23          18+
# 3        4                 Back to the Future            37           7+
# 5        6  Spider-Man: Into the Spider-Verse             4           7+
# 8        9            Raiders of the Lost Ark            41           7+
# 10      11                        Taxi Driver            46          18+
# ...    ...                                ...           ...          ...
# 5543  9302                       Own the Room             1           7+
# 5544  9310        Unidentified Flying Oddball            43          all
# 5546  9315                    'Twas the Night            21          all
# 5551  9345  The Story of the Animated Drawing            67          all
# 5553  9354                  The Liberty Story            65          all
#
#       IMDb  Rotten  Availability            Directors       Genres  \
# 1      8.7    87.0             1       Lana Wachowski       Action
# 3      8.5    96.0             1      Robert Zemeckis    Adventure
# 5      8.4    97.0             1      Bob Persichetti    Animation
# 8      8.4    95.0             1     Steven Spielberg       Action
# 10     8.3    95.0             1      Martin Scorsese        Crime
# ...    ...     ...           ...                  ...          ...
# 5543   6.4    46.0             1  Cristina Costantini  Documentary
# 5544   5.2    45.0             1        Russ Mayberry    Adventure
# 5546   5.3    45.0             1          Nick Castle       Comedy
# 5551   7.6    41.0             1     William Beaudine    Adventure
# 5553   7.4    40.0             1       Hamilton Luske    Adventure
#
#             Country Language  Runtime
# 1     United States  English    136.0
# 3     United States  English    116.0
# 5     United States  English    117.0
# 8     United States  English    115.0
# 10    United States  English    114.0
# ...             ...      ...      ...
# 5543  United States  English     91.0
# 5544  United States  English     93.0
# 5546  United States  English     84.0
# 5551  United States  English     60.0
# 5553  United States  English     60.0
#
# [5216 rows x 12 columns]

# %%
moviedata.describe()
# Out:
#                 ID  Age of Movie         IMDb       Rotten  Availability  \
# count  5216.000000   5216.000000  5216.000000  5216.000000   5216.000000
# mean   4354.276074     14.524156     6.179870    59.836273      1.057132
# std    2641.232006     13.671695     1.064067    22.375588      0.237022
# min       2.000000      1.000000     1.100000     2.000000      1.000000
# 25%    1982.750000      5.000000     5.600000    45.000000      1.000000
# 50%    4395.500000     10.000000     6.300000    60.000000      1.000000
# 75%    6769.250000     19.000000     6.900000    76.000000      1.000000
# max    9354.000000    102.000000     9.000000   100.000000      3.000000
#
#            Runtime
# count  5216.000000
# mean    100.319018
# std      14.473748
# min      60.000000
# 25%      90.000000
# 50%      98.000000
# 75%     109.000000
# max     140.000000

# %%
moviedata = moviedata.reset_index()
moviedata = moviedata.drop(columns = ['ID', 'index'])
ID = []
for i in range(1, len(moviedata) + 1):
    ID.append(i)
moviedata.insert(0, "ID", ID)
moviedata
# Out:
#         ID                              Title  Age of Movie Age Category  \
# 0        1                         The Matrix            23          18+
# 1        2                 Back to the Future            37           7+
# 2        3  Spider-Man: Into the Spider-Verse             4           7+
# 3        4            Raiders of the Lost Ark            41           7+
# 4        5                        Taxi Driver            46          18+
# ...    ...                                ...           ...          ...
# 5211  5212                       Own the Room             1           7+
# 5212  5213        Unidentified Flying Oddball            43          all
# 5213  5214                    'Twas the Night            21          all
# 5214  5215  The Story of the Animated Drawing            67          all
# 5215  5216                  The Liberty Story            65          all
#
#       IMDb  Rotten  Availability            Directors       Genres  \
# 0      8.7    87.0             1       Lana Wachowski       Action
# 1      8.5    96.0             1      Robert Zemeckis    Adventure
# 2      8.4    97.0             1      Bob Persichetti    Animation
# 3      8.4    95.0             1     Steven Spielberg       Action
# 4      8.3    95.0             1      Martin Scorsese        Crime
# ...    ...     ...           ...                  ...          ...
# 5211   6.4    46.0             1  Cristina Costantini  Documentary
# 5212   5.2    45.0             1        Russ Mayberry    Adventure
# 5213   5.3    45.0             1          Nick Castle       Comedy
# 5214   7.6    41.0             1     William Beaudine    Adventure
# 5215   7.4    40.0             1       Hamilton Luske    Adventure
#
#             Country Language  Runtime
# 0     United States  English    136.0
# 1     United States  English    116.0
# 2     United States  English    117.0
# 3     United States  English    115.0
# 4     United States  English    114.0
# ...             ...      ...      ...
# 5211  United States  English     91.0
# 5212  United States  English     93.0
# 5213  United States  English     84.0
# 5214  United States  English     60.0
# 5215  United States  English     60.0
#
# [5216 rows x 12 columns]

# %%
moviedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5216 entries, 0 to 5215
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            5216 non-null   int64
#  1   Title         5216 non-null   object
#  2   Age of Movie  5216 non-null   int64
#  3   Age Category  5216 non-null   object
#  4   IMDb          5216 non-null   float64
#  5   Rotten        5216 non-null   float64
#  6   Availability  5216 non-null   int64
#  7   Directors     5216 non-null   object
#  8   Genres        5216 non-null   object
#  9   Country       5216 non-null   object
#  10  Language      5216 non-null   object
#  11  Runtime       5216 non-null   float64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 489.1+ KB

# %% [markdown]
# Using Uni-Variate Linear Regression, test out various Numeric Variables to see which Variables can predict the IMDb Scores the most accurately.

# %% [markdown]
# Set up the Regression Problem with Train & Test Datasets

# %%
# Recall the Total-HP Dataset
IMDbScore = pd.DataFrame(moviedata['IMDb'])          # Response
Features = ['Age of Movie', 'Runtime', 'Rotten']     # Predictor

mse_train_list = []
mse_test_list = []

for col in Features:
    # Split the Dataset into Train and Test (Train: 80%, Test: 20%)
    Predictor = pd.DataFrame(moviedata[col])
    X_train, X_test, y_train, y_test = train_test_split(Predictor, IMDbScore, train_size = 0.8)

    # Linear Regression using Train Data
    linreg = LinearRegression()         # create the linear regression object
    linreg.fit(X_train, y_train)        # train the linear regression model

    # Coefficients of the Linear Regression line
    print('Intercept ({}):     b = {}'.format(col, linreg.intercept_))
    print('Coefficients ({}):  a = {}'.format(col, linreg.coef_))
    print()

    # Create a joint dataframe by concatenating the two variables
    jointdf = pd.concat([X_train, y_train], axis = 1).reindex(X_train.index)
    jointdf1 = pd.concat([X_train, y_train], axis = 1).reindex(X_train.index)
    # Calculate the correlation between the two columns/variables
    print(jointdf.corr())
    print()

    # Jointplot of Total Train against HP Train
    sb.jointplot(data = jointdf1, x = col, y = "IMDb", height = 10)
    
    # Formula for the Regression line
    regline_x = X_train
    regline_y = linreg.intercept_ + linreg.coef_ * X_train

    y_train_pred = linreg.predict(X_train)

    # Plot the Linear Regression line
    f, axes = plt.subplots(1, 2, figsize=(28, 12))

    axes[0].scatter(X_train, y_train)
    axes[0].plot(regline_x, regline_y, 'r-', linewidth = 3)
    axes[0].set_xlabel(col)
    axes[0].set_ylabel("IMDb Score")

    axes[1].scatter(X_train, y_train)
    axes[1].scatter(X_train, y_train_pred, color = "r")
    axes[1].set_xlabel(col)
    axes[1].set_ylabel("IMDb Score")

    # Predict Total values corresponding to HP
    y_train_pred = linreg.predict(X_train)
    y_test_pred = linreg.predict(X_test)

    # Check the Goodness of Fit (on Train Data)
    mse_train = mean_squared_error(y_train, y_train_pred)
    print("Goodness of Fit of {} (Train)".format(col))
    print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
    print("Mean Squared Error (MSE) \t:", mse_train)
    mse_train_list.append((col, mse_train))
    print()

    # Check the Goodness of Fit (on Test Data)
    mse_test = mean_squared_error(y_test, y_test_pred)
    print("Goodness of Fit of {} (Test)".format(col))
    print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
    print("Mean Squared Error (MSE) \t:", mse_test)
    mse_test_list.append((col, mse_test))
    print('\n' * 2)

    # Plot the Predictions vs the True values
    f, axes = plt.subplots(1, 2, figsize=(24, 12))
    axes[0].scatter(y_train, y_train_pred, color = "blue")
    axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
    axes[0].set_xlabel("True values of the Response Variable (Train)")
    axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
    axes[1].scatter(y_test, y_test_pred, color = "green")
    axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
    axes[1].set_xlabel("True values of the Response Variable (Test)")
    axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
# Out:
# Intercept (Age of Movie):     b = [6.03052061]
# Coefficients (Age of Movie):  a = [[0.0097532]]
#
#               Age of Movie      IMDb
# Age of Movie      1.000000  0.126124
# IMDb              0.126124  1.000000
#
# Goodness of Fit of Age of Movie (Train)
# Explained Variance (R^2) 	: 0.015907257823899346
# Mean Squared Error (MSE) 	: 1.1002529566544708
#
# Goodness of Fit of Age of Movie (Test)
# Explained Variance (R^2) 	: 0.01938114665444879
# Mean Squared Error (MSE) 	: 1.1638545563204077
#
#
#
# Intercept (Runtime):     b = [4.35128935]
# Coefficients (Runtime):  a = [[0.01817685]]
#
#           Runtime      IMDb
# Runtime  1.000000  0.245141
# IMDb     0.245141  1.000000
#
# Goodness of Fit of Runtime (Train)
# Explained Variance (R^2) 	: 0.060094269357592656
# Mean Squared Error (MSE) 	: 1.0737750124186694
#
# Goodness of Fit of Runtime (Test)
# Explained Variance (R^2) 	: 0.07543306864428079
# Mean Squared Error (MSE) 	: 1.007643206479603
#
#
#
# Intercept (Rotten):     b = [4.47040261]
# Coefficients (Rotten):  a = [[0.02851577]]
#
#           Rotten      IMDb
# Rotten  1.000000  0.594383
# IMDb    0.594383  1.000000
#
# Goodness of Fit of Rotten (Train)
# Explained Variance (R^2) 	: 0.35329160076845145
# Mean Squared Error (MSE) 	: 0.740152595074497
#
# Goodness of Fit of Rotten (Test)
# Explained Variance (R^2) 	: 0.31604997189715345
# Mean Squared Error (MSE) 	: 0.7401633790018737

# %%
# Find the variable with the most accurate model (the model whose MSE is the smallest)
def most_accurate(mse_train_list, mse_test_list):
    a = []
    b = []
    
    for i in mse_train_list:
        a.append(i[1])
    
    for i in mse_test_list:
        b.append(i[1]) 
        
    best_train = min(a)
    best_test = min(b)
   
    for i in range(0, len(mse_train_list)):
        if mse_train_list[i][1] == best_train:
            best_train = mse_train_list[i]
            
    for i in range(0, len(mse_test_list)):
        if mse_test_list[i][1] == best_test:
            best_test = mse_test_list[i]
    return best_train, best_test

# %%
most_accurate(mse_train_list, mse_test_list)
# Out:
# (('Rotten', 0.740152595074497), ('Rotten', 0.7401633790018737))

# %% [markdown]
# ## Conclu
# Conclude: Rotten Tomatoes Score model is the most accurate.
